# %% [markdown]
# # CSC4005 Lab 6 Demo – ViT for Smart Campus Scene Classification
#
# Notebook demo tối giản. Sinh viên nên chạy script chính bằng terminal để dễ quản lý W&B và output.

# %% [markdown]
# ## Ví dụ chạy bằng terminal
#
# ```bash
# python -m src.train --data_dir /path/to/mit_indoor_smartcampus_5 --use_wandb
# ```

# %%
from pathlib import Path
print(Path.cwd())
print('Use terminal command in README.md for training.')
